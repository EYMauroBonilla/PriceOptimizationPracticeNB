# %%
# Import the reqiured libraries
import pandas as pd
import numpy as np
import statsmodels.api as sm
from statsmodels.formula.api import ols
import matplotlib.pyplot as plt
import seaborn as sns; sns.set(style="ticks", color_codes=True)
## Get multiple outputs in the same cell
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

## Ignore all warnings
import warnings
warnings.filterwarnings('ignore')
warnings.filterwarnings(action='ignore', category=DeprecationWarning)
## Display all rows and columns of a dataframe instead of a truncated version
from IPython.display import display
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
sold = pd.read_csv(r'C:\Users\AW581PP\OneDrive - EY\Documents\EY D&A\nocode-ml-example\data\Cafe - Sell Meta Data.csv')
transactions = pd.read_csv(r'C:\Users\AW581PP\OneDrive - EY\Documents\EY D&A\nocode-ml-example\data\Cafe - Transaction - Store.csv')
date_info = pd.read_csv(r'C:\Users\AW581PP\OneDrive - EY\Documents\EY D&A\nocode-ml-example\data\DateInfo.csv')

# %%
sold.describe()
sold.describe(include = ['O'])
# Out:
#            SELL_ID  SELL_CATEGORY      ITEM_ID      COSTS  MIN_PRICE  \
# count    11.000000      11.000000    11.000000  11.000000  11.000000
# mean   2235.000000       1.272727  5906.909091   5.772727   6.927273
# std     598.728653       1.009050  1830.217170   2.562846   3.075416
# min    1070.000000       0.000000  3052.000000   1.000000   1.200000
# 25%    2051.500000       0.000000  5030.000000   4.500000   5.400000
# 50%    2053.000000       2.000000  6249.000000   7.000000   8.400000
# 75%    2540.500000       2.000000  7821.000000   7.750000   9.300000
# max    3067.000000       2.000000  7821.000000   8.000000   9.600000
#
#        MAX_PRICE
# count  11.000000
# mean   21.927273
# std     3.075416
# min    16.200000
# 25%    20.400000
# 50%    23.400000
# 75%    24.300000
# max    24.600000
#        ITEM_NAME
# count         11
# unique         4
# top       BURGER
# freq           4

# %%
dfTrans=pd.read_csv(r'C:\Users\AW581PP\OneDrive - EY\Documents\EY D&A\nocode-ml-example\data\Cafe - Transaction - Store.csv')

# %%
dfTrans.head(5)
# Out:
#    STORE CALENDAR_DATE  PRICE  QUANTITY  SELL_ID  SELL_CATEGORY
# 0      1        1/1/12  15.50        46     1070              0
# 1      1        1/1/12  12.73        22     2051              2
# 2      1        1/1/12  12.75        18     2052              2
# 3      1        1/1/12  12.60        30     2053              2
# 4      1        1/2/12  15.50        70     1070              0

# %%
sold.head()
# Out:
#    SELL_ID  SELL_CATEGORY  ITEM_ID ITEM_NAME  COSTS  MIN_PRICE  MAX_PRICE
# 0     1070              0     7821    BURGER    8.0        9.6       24.6
# 1     3055              0     3052    COFFEE    1.0        1.2       16.2
# 2     3067              0     5030      COKE    3.0        3.6       18.6
# 3     3028              0     6249  LEMONADE    2.0        2.4       17.4
# 4     2051              2     7821    BURGER    6.0        7.2       22.2

# %%
sns.pairplot(sold)
